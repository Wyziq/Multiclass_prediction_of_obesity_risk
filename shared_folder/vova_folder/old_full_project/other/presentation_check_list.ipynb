# %% [markdown]
# <div style="
#   padding: 18px 24px;
#   margin-top: 15px;
#   margin-bottom: 25px;
#   border-left: 6px solid var(--jp-info-color0);
#   background: var(--jp-layout-color2);
#   border-radius: 8px;
# ">
# <h1 style="margin:0; color:var(--jp-ui-font-color1);">
# Чек-лист готовности к презентации
# </h1>
# </div>

# %% [markdown]
# <input type="checkbox"> Четко сформулирована проблема и цель проекта<br>
# <input type="checkbox"> Готов работающий прототип (или демо-версия)<br>
# <input type="checkbox"> Основной функционал корректно работает<br>
# <input type="checkbox"> Подготовлены визуальные материалы (слайды, демо, диаграммы)<br>
# <input type="checkbox"> Распределены роли: кто что рассказывает на защите<br>
# <input type="checkbox"> Отрепетирована презентация<br>
# <input type="checkbox"> Учтены возможные вопросы от жюри / слушателей<br>
# <input type="checkbox"> Презентация укладывается в отведенное время<br>
# <input type="checkbox"> В презентации есть слайды о целях и желаемых результатах<br>
# <input type="checkbox"> В презентации есть слайды о распределении ролей<br>
# <input type="checkbox"> В презентации есть слайды о планировании ресурсов и инструментов<br>
# <input type="checkbox"> В презентации есть слайды о каждом этапе работы над проектом<br>
