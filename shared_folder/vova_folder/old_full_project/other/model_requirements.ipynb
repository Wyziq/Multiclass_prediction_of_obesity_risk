# %% [markdown]
# <div style="
#   padding: 18px 24px;
#   margin-top: 15px;
#   margin-bottom: 25px;
#   border-left: 6px solid var(--jp-info-color0);
#   background: var(--jp-layout-color2);
#   border-radius: 8px;
# ">
# <h1 style="margin:0; color:var(--jp-ui-font-color1);">
# Требования к моделям
# </h1>
# </div>

# %% [markdown]
# <h3 style="
#     /* color: var(--jp-ui-font-color1);  */
#     margin-top: 22px;
# ">
# Линейная регрессия
# </h3>
#
# | Элемент | Описание / Ответ команды | Ваш ответ |
# | --- | --- | --- |
# | Цель анализа | Какую зависимость вы моделируете? |
# | Зависимая переменная (target) |  |
# | Независимые переменные (features) |  |
# | Метод построения модели | (например: LinearRegression в sklearn) |  |
# | Проверка качества модели (метрики) | MSE, R² и т.д. |  |
# | Основные выводы | Что показала модель, насколько предсказания разумны? |  |

# %% [markdown]
# <h3 style="
#     /* color: var(--jp-ui-font-color1);  */
#     margin-top: 22px;
# ">
# Логистическая регрессия
# </h3>
#
# | Элемент | Описание / Ответ команды | Ваш ответ |
# | --- | --- | --- |
# | Цель задачи | Что классифицируется (0/1)? |  |
# | Целевая переменная |  |  |
# | Основные признаки |  |  |
# | Интерпретация коэффициентов| Как влияет каждый признак? |  |
# | Метрики качества| Accuracy, F1-score, ROC-AUC |  |
# | Выводы| Какие факторы определяют вероятность класса? |  |

# %% [markdown]
# <h3 style="
#     /* color: var(--jp-ui-font-color1);  */
#     margin-top: 22px;
# ">
# Деревья решений
# </h3>
#
# | Элемент | Описание / Ответ команды | Ваш ответ |
# | --- | --- | --- |
# | Поставленная задача | Какую задачу решали? |  |
# | Этапы подготовки данных | Очистка, кодирование, нормализация |  |
# | Модель | DecisionTree или RandomForest |  |
# | Глубина / параметры дерева |  |  |
# | Feature importance | Важнейшие признаки |  |
# | Выводы и интерпретация | Как модель «принимает» решения? |  |

# %% [markdown]
# <h3 style="
#     /* color: var(--jp-ui-font-color1);  */
#     margin-top: 22px;
# ">
# Feature Importance и подбор гиперпараметров
# </h3>
#
# | Элемент | Описание / Ответ команды | Ваш ответ |
# | --- | --- | --- |
# | Цель эксперимента | Что именно оптимизировали? |  |
# | Базовая модель |  |  |
# | Методы подбора гиперпараметров | GridSearchCV, RandomSearch, Optuna |  |
# | Основные найденные параметры |  |  |
# | Feature importance | Топ-5 значимых признаков |  |
# | Выводы | Как улучшились метрики, какие признаки влияют сильнее? |  |

# %% [markdown]
# <h3 style="
#     /* color: var(--jp-ui-font-color1);  */
#     margin-top: 22px;
# ">
# Подготовка текстовых данных и кластеризация
# </h3>
#
# | Элемент | Описание / Ответ команды | Ваш ответ |
# | --- | --- | --- |
# | Источник данных | Откуда тексты? | |
# | Этапы очистки данных | Токенизация, лемматизация, удаление стоп-слов |  |
# | Векторизация текста | TF-IDF, CountVectorizer и др. |  |
# | Метод кластеризации | K-Means, DBSCAN |  |
# | Интерпретация кластеров | Что объединяет объекты внутри кластера? |  |
# | Выводы | Какие закономерности выявлены по темам? |  |

# %% [markdown]
# <h3 style="
#     /* color: var(--jp-ui-font-color1);  */
#     margin-top: 22px;
# ">
# Ансамблевые методы
# </h3>
#
# | Элемент | Описание / Ответ команды | Ваш ответ |
# | --- | --- | --- |
# | Тип ансамбля | Bagging / Boosting / Stacking  |  |
# | Использованные модели | RandomForest, XGBoost, LightGBM, CatBoost  |  |
# | Методы настройки | Подбор параметров, регуляризация  |  |
# | Метрики качества | ROC-AUC, R², F1-score  |  |
# | Feature importance |  |  |
# | Основные выводы | Как ансамбль улучшил точность предсказаний?  |  |
