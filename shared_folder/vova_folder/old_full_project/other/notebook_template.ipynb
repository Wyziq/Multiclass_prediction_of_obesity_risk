# %% [markdown]
# <div style="
#   padding: 18px 24px;
#   margin-top: 15px;
#   margin-bottom: 25px;
#   border-left: 6px solid var(--jp-info-color0);
#   background: var(--jp-layout-color2);
#   border-radius: 8px;
# ">
# <h1 style="margin:0; color:var(--jp-ui-font-color1);">
# Название ноутбука
# </h1>
# <p style="font-size: 1.1em; color: var(--jp-ui-font-color1); margin-top: 6px;">
# Короткое описание цели ноутбука (1–2 предложения).
# </p>
# </div>

# %% [markdown]
# <h2 style="
#   padding: 6px 0;
#   border-bottom: 2px solid var(--jp-border-color2);
#   /* color: var(--jp-ui-font-color1); */
#   margin-top: 32px;
# ">
# 01 Название раздела
# </h2>

# %% [markdown]
# <h3 style="
#     /* color: var(--jp-ui-font-color1);  */
#     margin-top: 22px;
# ">
# 1.1 Подраздел
# </h3>
#
# <p>
# Тут можно написать текст
# <code>тут код</code>
# </p>

# %% [markdown]
# Основная часть текста содержится в Markdown.
# Можно использовать **выделения**, списки и т.д.
#
# - пункт 1
# - пункт 2
# - пункт 3

# %% [markdown]
# | Column | Description | Notes |
# |--------|-------------|-------|
# | Age    | Age of person | 14–61 |
# | Weight | Body weight | kg |
# | CH2O   | Water consumption | liters/day |

# %% [markdown]
# <span style="color: var(--jp-info-color1); font-weight: 600;">
# Это выделенный синим текст внутри абзаца.
# </span>

# %% [markdown]
# <span style="color: var(--jp-success-color1); font-weight: 600;">
# Это выделение зелёным как акцент.
# </span>

# %% [markdown]
# Здесь мы видим влияние
# <span style="background: color-mix(in srgb, #f7e56d 60%, transparent); padding:2px 4px; border-radius:4px;">
# частого употребления высококалорийной еды
# </span>
# на целевую метрику.

# %% [markdown]
# <span style="
#   background: color-mix(in srgb, #6eee8a 50%, transparent);
#   padding: 2px 4px;
#   border-radius: 4px;
# ">
# зелёное выделение
# </span>

# %% [markdown]
# <div style="
#   border-left: 4px solid var(--jp-warn-color0);
#   background: var(--jp-layout-color2);
#   padding: 12px 14px;
#   border-radius: 6px;
#   margin: 12px 0;
#   color: var(--jp-ui-font-color1);
# ">
# <strong>⚠️ Предупреждение:</strong><br>
# В данных обнаружены пропуски. Проверьте заполнение перед обучением моделей.
# </div>

# %% [markdown]
# <div style="
#   border-left: 4px solid #3a3a3a;
#   background: var(--jp-layout-color2);
#   padding: 12px 14px;
#   border-radius: 6px;
#   margin: 12px 0;
#   color: var(--jp-ui-font-color1);
# ">
# <strong>ℹ️ Информация:</strong><br>
# Данные содержат 17 признаков и целевую переменную.
# </div>

# %% [markdown]
# <div style="
#   border-left: 4px solid var(--jp-success-color0);
#   background: var(--jp-layout-color2);
#   padding: 12px 14px;
#   border-radius: 6px;
#   margin: 12px 0;
#   color: var(--jp-ui-font-color1);
# ">
# <strong>✅ Вывод:</strong><br>
# Модель RandomForest показала наиболее стабильный результат в базовых экспериментах.
# </div>

# %% [markdown]
# <div style="
#   border-left: 4px solid var(--jp-info-color0);
#   background: var(--jp-layout-color2);
#   padding: 12px 14px;
#   border-radius: 6px;
#   margin: 12px 0;
#   color: var(--jp-ui-font-color1);
# ">
# <strong>❓ Вопросы для исследования:</strong>
# <ul style="margin-top: 6px;">
# <li>Есть ли связь между потреблением жирной пищи и уровнем ожирения?</li>
# <li>Какие признаки сильнее всего коррелируют с <code>NObeyesdad</code>?</li>
# <li>Как физическая активность влияет на целевую метрику?</li>
# </ul>
# </div>

# %% [markdown]
# <div style="
#   border-left: 4px solid var(--jp-border-color2);
#   background: var(--jp-layout-color2);
#   padding: 10px 12px;
#   border-radius: 6px;
#   margin: 10px 0;
#   color: var(--jp-ui-font-color1);
# ">
# <strong>📝 Заметка:</strong> Проверить корректность типов колонок после загрузки данных.
# </div>

# %% [markdown]
# <div style="
#   border: 1px solid var(--jp-info-color0);
#   padding: 8px 12px;
#   border-radius: 6px;
#   /* color: var(--jp-ui-font-color1); */
# ">
# 🔷 Текст с синей рамкой — выглядит аккуратно и читабельно.
# </div>
